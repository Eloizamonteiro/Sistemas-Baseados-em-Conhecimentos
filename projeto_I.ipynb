# %% [markdown]
# <a href="https://colab.research.google.com/github/Eloizamonteiro/Sistemas-Baseados-em-Conhecimentos/blob/main/projeto_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install experta
print('Uninstalling old frozendict and installing a compatible version...')
# !pip install --upgrade frozendict
# Out:
# Collecting experta
#   Downloading experta-1.9.4-py3-none-any.whl.metadata (5.0 kB)
# Collecting frozendict==1.2 (from experta)
#   Downloading frozendict-1.2.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting schema==0.6.7 (from experta)
#   Downloading schema-0.6.7-py2.py3-none-any.whl.metadata (14 kB)
# Downloading experta-1.9.4-py3-none-any.whl (35 kB)
# Downloading schema-0.6.7-py2.py3-none-any.whl (14 kB)
# Building wheels for collected packages: frozendict
#   Building wheel for frozendict (setup.py) ... done
#   Created wheel for frozendict: filename=frozendict-1.2-py3-none-any.whl size=3149 sha256=d76c14f088625be1306f67782f3a47c7206375f8520ddab533cc0a74d232fce5
#   Stored in directory: /root/.cache/pip/wheels/f6/ff/aa/750fec7bf9618d87b53572def5abf3e098f853cc5ab4147656
# Successfully built frozendict
# Installing collected packages: schema, frozendict, experta
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.4.7
#     Uninstalling frozendict-2.4.7:
#       Successfully uninstalled frozendict-2.4.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.66 requires frozendict>=2.3.4, but you have frozendict 1.2 which is incompatible.
# Successfully installed experta-1.9.4 frozendict-1.2 schema-0.6.7
# Uninstalling old frozendict and installing a compatible version...
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (1.2)
# Collecting frozendict
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Installing collected packages: frozendict
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 1.2
#     Uninstalling frozendict-1.2:
#       Successfully uninstalled frozendict-1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# experta 1.9.4 requires frozendict==1.2, but you have frozendict 2.4.7 which is incompatible.
# Successfully installed frozendict-2.4.7

# %%
from experta import KnowledgeEngine, Rule, Fact, MATCH, AS
from experta import P    # predicates (e.g. P(lambda x: x > 37.8))
from experta import OR, AND, NOT

# %%
class Plantacao(Fact):
  # Informações observadas na plantação
  pass

# %%
from experta import *

# =========================
# FATO PRINCIPAL
# =========================
class Plantacao(Fact):
    pass


class SBCPlantacao(KnowledgeEngine):

    def __init__(self):
        super().__init__()
        self.diagnostico = []
        self.recomendacoes = []

    # ======================================================
    # 🔴 NUTRIÇÃO (R1–R5)
    # ======================================================

    @Rule(Plantacao(folhas_amarelas=True))
    def r1(self):
        print("R1 → Suspeita de deficiência nutricional")
        self.declare(Fact(def_nutricional=True))

    @Rule(Fact(def_nutricional=True),
          Plantacao(crescimento_lento=True))
    def r2(self):
        print("R2 → Deficiência de nitrogênio")
        self.declare(Fact(def_nitrogenio=True))

    @Rule(Fact(def_nitrogenio=True))
    def r3(self):
        print("R3 → Aplicar adubação nitrogenada")
        self.diagnostico.append("Deficiência de nitrogênio")
        self.recomendacoes.append("Adubação nitrogenada")

    @Rule(Fact(def_nitrogenio=True))
    def r4(self):
        print("R4 → Plano de correção nutricional criado")
        self.diagnostico.append("Correção nutricional")

    @Rule(Fact(def_nitrogenio=True))
    def r5(self):
        print("R5 → Monitorar recuperação da planta")

    # ======================================================
    # 🔵 IRRIGAÇÃO (R6–R10)
    # ======================================================

    @Rule(Plantacao(solo_seco=True))
    def r6(self):
        print("R6 → Falta de irrigação suspeita")
        self.declare(Fact(falta_agua=True))

    @Rule(Fact(falta_agua=True),
          Plantacao(folhas_murchas=True))
    def r7(self):
        print("R7 → Estresse hídrico")
        self.declare(Fact(estresse_hidrico=True))

    @Rule(Fact(estresse_hidrico=True))
    def r8(self):
        print("R8 → Aumentar irrigação")
        self.recomendacoes.append("Aumentar irrigação")

    @Rule(Fact(estresse_hidrico=True))
    def r9(self):
        print("R9 → Plano de irrigação criado")

    @Rule(Fact(estresse_hidrico=True))
    def r10(self):
        print("R10 → Monitorar umidade do solo")

    # ======================================================
    # 🟢 FUNGOS (R11–R15)
    # ======================================================

    @Rule(Plantacao(manchas_escuras=True))
    def r11(self):
        print("R11 → Suspeita de fungos")
        self.declare(Fact(doenca_fungo=True))

    @Rule(Fact(doenca_fungo=True),
          Plantacao(alta_umidade=True))
    def r12(self):
        print("R12 → Risco elevado de fungos")
        self.declare(Fact(risco_fungo=True))

    @Rule(Fact(risco_fungo=True))
    def r13(self):
        print("R13 → Aplicar fungicida")
        self.recomendacoes.append("Fungicida")

    @Rule(Fact(risco_fungo=True))
    def r14(self):
        print("R14 → Monitorar doença fúngica")

    @Rule(Fact(risco_fungo=True),
          NOT(Fact(fungicida_aplicado=True)),
          salience=10)
    def r15(self):
        print("R15 🔥 ALERTA: fungicida não aplicado!")

    # ======================================================
    # 🟡 PRAGAS (R16–R20)
    # ======================================================

    @Rule(Plantacao(folhas_perfuradas=True))
    def r16(self):
        print("R16 → Suspeita de insetos")
        self.declare(Fact(insetos=True))

    @Rule(Fact(insetos=True),
          Plantacao(presenca_lagartas=True))
    def r17(self):
        print("R17 → Infestação por lagartas")
        self.declare(Fact(lagartas=True))

    @Rule(Fact(lagartas=True))
    def r18(self):
        print("R18 → Controle biológico recomendado")
        self.recomendacoes.append("Controle biológico")

    @Rule(Fact(lagartas=True),
          Plantacao(dano_severo=True))
    def r19(self):
        print("R19 → Controle químico necessário")
        self.declare(Fact(controle_quimico=True))

    @Rule(Fact(controle_quimico=True),
          salience=5)
    def r20(self):
        print("R20 → ALERTA: controle químico urgente!")

# %%
# Plantação com dificiência nutricional
engine = DiagnosticoPlantacao()
engine.reset()

engine.declare(
    Plantacao(
        folhas_amarelas=True,
        crescimento_lento=True
    )
)

engine.run()
# Out:
# R1 -> Folhas amarelas: suspeita de deficiência nutricional
# R2 -> Deficiência nutricional + crescimento lento: falta de nitrogênio
# R3 -> Diagnóstico: deficiência de nitrogênio
# R4 -> Ação: aplicar adubação nitrogenada
# R5 -> Monitorar recuperação nutricional

# %%
# Estresse Hídrico
engine = DiagnosticoPlantacao()
engine.reset()

engine.declare(
    Plantacao(
        solo_seco=True,
        folhas_murchas=True
    )
)

engine.run()
# Out:
# R6 -> Solo seco: suspeita de falta de irrigação
# R7 -> Falta de água + murcha: estresse hídrico
# R8 -> Recomendação: aumentar irrigação
# R9 -> Criar plano de irrigação
# R10 -> Monitorar umidade do solo

# %%
# Doença Fúngica
engine = DiagnosticoPlantacao()
engine.reset()

engine.declare(
    Plantacao(
        manchas_escuras=True,
        alta_umidade=True
    )
)

engine.run()
# Out:
# R11 -> Manchas escuras: suspeita de fungos
# R12 -> Umidade alta + fungo: risco elevado
# R15 ALERTA: risco alto de fungos sem tratamento!
# R13 -> Recomendar fungicida
# R14 -> Monitorar evolução da doença

# %%
#Infestação por pragas
engine = DiagnosticoPlantacao()
engine.reset()

engine.declare(
    Plantacao(
        folhas_perfuradas=True,
        presenca_lagartas=True,
        dano_severo=True
    )
)

engine.run()
# Out:
# R16 -> Folhas perfuradas: suspeita de insetos
# R17 -> Infestação por lagartas detectada
# R19 -> Dano severo: controle químico necessário
# R20 -> ALERTA: aplicação química urgente!
# R18 -> Recomendação: controle biológico
